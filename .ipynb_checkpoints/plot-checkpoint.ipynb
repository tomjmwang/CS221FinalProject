# %%
import matplotlib.pyplot as plt
import numpy as np
import pickle
from collections import defaultdict
import collections

# %%
def readFile(filename):
    player2SimpleQl_x = [1]
    player2SimpleQl_y = [0.5]
    with open(filename) as f:
        content = f.readlines()
        for line in content:
            if 'iterations:' in line:
                lineList = line.rstrip().split(' ')
                player2SimpleQl_x += [int(lineList[0])]
                player2SimpleQl_y+= [float(lineList[-1])]
    return player2SimpleQl_x, player2SimpleQl_y

# %%
filename = './q_learning/win_rates_random_2.txt'
player2RandomQl_x, player2RandomQl_y = readFile(filename)

# %%
filename = './q_learning/win_rates_simple_2.txt'
player2SimpleQl_x, player2SimpleQl_y = readFile(filename)

# %%
plt.plot(player2RandomQl_x, player2RandomQl_y,label='Random')
plt.plot(player2SimpleQl_x,player2SimpleQl_y,label='Simple')
plt.title('Win Rate for 2 agents')
plt.xlabel('Iterations')
plt.ylabel('Win Rate')
first_legend = plt.legend()
plt.show()

# %%
def plot_bar(data):
    actionMap = defaultdict(int)
    for i in data.items():
        action = i[0][1][0]
        actionMap[action]+=1 
    actionMap = collections.OrderedDict(sorted(actionMap.items()))
    print('Total states:', np.sum(list(actionMap.values())))
    # Make a fake dataset:
    height = list(actionMap.values())
    bars = list(actionMap.keys())
    y_pos = np.arange(len(bars))
    # Create bars
    plt.bar(y_pos, height) 
    # Create names on the x-axis
    plt.xticks(y_pos, bars)
    plt.xticks(rotation=90)
    plt.title('Action frequency for policy by Q-learning for 2 agents')
    plt.xlabel('Action')
    plt.ylabel('Count') 
    # Show graphic
    plt.show()

# %%
file = open('./q_learning/q_data_simple_2_150000', 'rb')
# dump information to that file
data = pickle.load(file)
# close the file
file.close()
plot_bar(data)
# Out:
# Total states: 184364

# %%
file = open('./q_learning/q_data_random_2_150000', 'rb')
# dump information to that file
data = pickle.load(file)
# close the file
file.close()
plot_bar(data)
# Out:
# Total states: 153437
